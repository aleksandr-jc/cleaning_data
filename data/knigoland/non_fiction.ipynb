# %%
import pandas as pd

# %%
input_file = 'xlsx/knigoland_non_fiction.xlsx'
output_file = 'csv/knigoland_non_fiction.csv'

df = pd.read_excel(input_file)
# df.to_csv(output_file, index=False)

# %%
df.head(5)
# Out:
#        Імʼя автора                                  Назва книги  \
# 0        Феррис С.                                         Інґа
# 1              NaN         Блиск і полум’я. Біографія діамантів
# 2  Харукі Муракамі         Про що я говорю, коли говорю про біг
# 3         Обама Б.  Мрії мого батька. Історія про расу і спадок
# 4       Вудворд Б.                   Страх. Трамп у Білому домі
#
#               Мова Перекладач  Мова оригіналу  Оригінальна назва  \
# 0  Українська мова        NaN             NaN                NaN
# 1  Українська мова        NaN             NaN                NaN
# 2  Українська мова        NaN             NaN                NaN
# 3  Українська мова        NaN             NaN                NaN
# 4  Українська мова        NaN             NaN                NaN
#
#         Назва видавця  Рік видання           ISBN            Жанр книги
# 0  Yakaboo Publishing       2018.0  9789669763327  Біографії та мемуари
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3937 entries, 0 to 3936
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Імʼя автора        3197 non-null   object
#  1   Назва книги        3937 non-null   object
#  2   Мова               3892 non-null   object
#  3   Перекладач         5 non-null      object
#  4   Мова оригіналу     0 non-null      float64
#  5   Оригінальна назва  0 non-null      float64
#  6   Назва видавця      3937 non-null   object
#  7   Рік видання        3899 non-null   float64
#  8   ISBN               3736 non-null   object
#  9   Жанр книги         3937 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 307.7+ KB

# %%
df_filter = df[df['Назва книги'].str.contains('Карта', case=False, na=False)]


df_filter
# Out:
#        Імʼя автора                                        Назва книги  \
# 2236    Эрин Мейер  «Культурна карта. Бар’єри міжкультурного спілк...
# 2671  Деніел Єрґін  Нова карта світу. Енергетика, клімат, конфлікт...
#
#                  Мова Перекладач  Мова оригіналу  Оригінальна назва  \
# 2236  Українська мова        NaN             NaN                NaN
# 2671  Українська мова        NaN             NaN                NaN
#
#      Назва видавця  Рік видання           ISBN                      Жанр книги
# 2236    Наш формат       2021.0  9786177863297  Кар'єра, особиста ефективність
# 2671   Лабораторія       2022.0  9786178053260              Загальна економіка

# %%
df.to_csv(output_file, index=False)
