# %%
import pandas as pd

# %%
input_file = 'xlsx/knigoland_preschool.xlsx'

output_file = 'csv/knigoland_preschool.csv'


df = pd.read_excel(input_file)


print(f' Кількість книжок: {df.shape[0]}')
# Out:
#  Кількість книжок: 3168

# %%
df_filter = df[df['Назва книги'].str.contains(r'^Книга', regex=True, case=False, na=False)]

df_filter
# Out:
# Empty DataFrame
# Columns: [Імʼя автора, Назва книги, Мова, Перекладач, Мова оригіналу, Оригінальна назва, Назва видавця, Рік видання, ISBN, Жанр книги]
# Index: []

# %%
df_filter_isbn = df[df['ISBN'].astype(str).str.contains(r'^2', regex=True)]
df_filter_isbn.index
# Out:
# Index([ 165,  170,  199,  220,  237,  238,  245,  315,  362,  456,  540,  611,
#         612,  615,  623,  624,  625,  751,  812,  897,  931,  937, 1059, 1060,
#        1434, 1532, 1580, 1612, 1754, 1766, 1890, 2022, 2050, 2098, 2099, 2106,
#        2109, 2277, 2348, 2469, 2533],
#       dtype='int64')

# %%
df.drop(index=df_filter_isbn.index, inplace=True)

# %%
df_filter = df[df['ISBN'].isnull()]
df_filter
# Out:
#      Імʼя автора                                        Назва книги  \
# 335     Сіліч С.               Тренажер дошкільника. Учимося лічити
# 336     Сіліч С.               Тренажер дошкільника. Учимося читати
# 337     Сіліч С.  Тренажер дошкільника. Учимося писати літери та...
# 338    Цибань І.         Прописи та лабіринти. У пошуках ласощів 3+
# 339    Цибань І.              Прописи та лабіринти. Суперпригоди 5+
# ...          ...                                                ...
# 2711         NaN                           Моє портфоліо(укр.стиль)
# 2799         NaN    Интерьерные наклейки.Щенячий патруль(синий фон)
# 2810         NaN        НУШ 2 клас СУПЕРТРЕНАЖЕР з української мови
# 2813         NaN               Набір карток.Таблиця Множення.Олівці
# 2912         NaN                  Скринька-памʼятайка. Світ довкола
#
#                  Мова  Перекладач  Мова оригіналу  Оригінальна назва  \
# 335   Українська мова         NaN             NaN                NaN
# ...

# %%
df_filter = df[df['Жанр книги'].str.contains('Демонстраційні матеріали')]
# x = df_filter[df_filter['ISBN'].astype(str).str.contains(r'^4', regex=True)]
df.drop(index=df_filter.index, inplace=True)

# %%
df_filter = df[df['ISBN'].astype(str).str.contains(r'^4', regex=True)]
df_filter
df.drop(index=df_filter.index, inplace=True)

# %%
df_filter = df[df['ISBN'].astype(str).str.contains(r'^9', regex=True)]
df_filter
# Out:
#                    Імʼя автора  \
# 0                Муренець О.Г.
# 1     Каспарова Юлія Вадимівна
# 2     Каспарова Юлія Вадимівна
# 3                          NaN
# 4                 Цепова І. В.
# ...                        ...
# 3163               Шушкевич А.
# 3164           Руслан Ярошенко
# 3165               Іван Алекса
# 3166             Федiенко В.В.
# 3167                Беденко М.
#
#                                             Назва книги  \
# 0                            Лео та Ліз досліджують дім
# 1                                       Лісовий концерт
# 2                                    Неслухняні тарілки
# 3                       Ми з України. Корисні дрібнички
# 4     Мій перший зошит. Прописи для лівшів. 1 клас. ...
# ...                                                 ...
# 3163  Народна лялька на кукурудзяному качані 5-6 кл....
# 3164  ANIMALS. Посiбник для позакласного читання з а...
# 3165  Nick and Lilly: At the nursery school - дитяча...
# ...

# %%
df.shape
# Out:
# (2622, 10)

# %%
x = 2622 - 2314
x
# Out:
# 308

# %%
df_filter = df[df['ISBN'].isnull()]
df_filter.groupby('Жанр книги').count()
# Out:
#                                 Імʼя автора  Назва книги  Мова  Перекладач  \
# Жанр книги
# Інклюзивна освіта                         1            1     1           0
# Іноземні мови                            70          112   112           0
# Довкілля                                  1            3     3           0
# Логіка                                    0            1     1           0
# Логіка і мислення                         1            3     3           0
# Математика, рахування                    15           25    25           0
# Методика для вихователів                  4           10    10           0
# Письмо, прописи, моторика                30           47    47           0
# Розвиток загальних здібностей            26           35    35           0
# Розвиток мови, логопедія                  1            3     3           0
# Розвиток пам'яті, уваги і уяви            0            3     3           0
# ...

# %%
df_filter = df[df['Жанр книги'].isnull()]
df_filter
# Out:
# Empty DataFrame
# Columns: [Імʼя автора, Назва книги, Мова, Перекладач, Мова оригіналу, Оригінальна назва, Назва видавця, Рік видання, ISBN, Жанр книги]
# Index: []

# %%
df_filter = df.groupby('Жанр книги').count()
df_filter
# Out:
#                                 Імʼя автора  Назва книги  Мова  Перекладач  \
# Жанр книги
# Інклюзивна освіта                         1           27    27           0
# Іноземні мови                           298          577   532           0
# Історія, право                            1            1     1           0
# Виховання дітей                           1            1     1           0
# Довкілля                                 32          107   107           0
# Дошкільне навчання                       12           15    15           0
# Дітям 5-6                                 1            1     1           0
# Екологія                                  3            4     4           0
# Кольори, форми                            2           12    12           0
# Логіка                                    3            8     7           0
# Логіка і мислення                        33           84    76           0
# ...

# %%
df_filter = df[df['ISBN'].isnull()]
df_filter
# Out:
#      Імʼя автора                                        Назва книги  \
# 335     Сіліч С.               Тренажер дошкільника. Учимося лічити
# 336     Сіліч С.               Тренажер дошкільника. Учимося читати
# 337     Сіліч С.  Тренажер дошкільника. Учимося писати літери та...
# 338    Цибань І.         Прописи та лабіринти. У пошуках ласощів 3+
# 339    Цибань І.              Прописи та лабіринти. Суперпригоди 5+
# ...          ...                                                ...
# 2327         NaN  ЗОЛОТИЙ ВІНОЧОК 4 кл. Зошит. Учуся працювати з...
# 2651         NaN                       Багаторазові блокноти. Лінії
# 2668         NaN  Английский для дошкольников Подарок маленькому...
# 2810         NaN        НУШ 2 клас СУПЕРТРЕНАЖЕР з української мови
# 2912         NaN                  Скринька-памʼятайка. Світ довкола
#
#                       Мова  Перекладач  Мова оригіналу  Оригінальна назва  \
# 335        Українська мова         NaN             NaN                NaN
# ...

# %%
df.shape
# Out:
# (2590, 10)

# %%
df.to_csv(output_file, index=False)
