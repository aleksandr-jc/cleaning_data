# %%
import pandas as pd
import numpy as np

# %%
input_file = 'book_data.xlsx'
df = pd.read_excel(input_file)

df.head()
# Out:
#                           Імʼя автора  \
# 0                     Ірина Потапенко
# 1  Неоніла Зайченко,Сусанна Воробйова
# 2             Гавриш Н.,Косенчук О.Г.
# 3                      О. К. Русанова
# 4                          Ванжа С.М.
#
#                                          Назва книги                     Мова  \
# 0  STEM-освіта в початковій школі: від навчальної...          Українська мова
# 1     Практичний курс української мови для іноземців  Українська / Англійська
# 2  Парціальна програма з національно-патріотичног...          Українська мова
# 3    Хімія 7 клас. Мій конспект. Матеріали до уроків          Українська мова
# 4   Розгорнутий календарний план. Літо. Молодший вік          Українська мова
#
#   Перекладач Мова оригіналу Оригінальна назва   Назва видавця Рік видання  \
# 0        NaN            NaN               NaN           Ранок        2024
# 1        NaN            NaN               NaN  Знання України        2005
# ...

# %%
df[["Укладач", "Ілюстратор", "Тираж"]] = np.nan

# %%
df = df.drop(['Unnamed: 1', 'Unnamed: 2', 'knigoland_students'], axis=1)
df.head()
# Out:
#                           Імʼя автора  \
# 0                     Ірина Потапенко
# 1  Неоніла Зайченко,Сусанна Воробйова
# 2             Гавриш Н.,Косенчук О.Г.
# 3                      О. К. Русанова
# 4                          Ванжа С.М.
#
#                                          Назва книги                     Мова  \
# 0  STEM-освіта в початковій школі: від навчальної...          Українська мова
# 1     Практичний курс української мови для іноземців  Українська / Англійська
# 2  Парціальна програма з національно-патріотичног...          Українська мова
# 3    Хімія 7 клас. Мій конспект. Матеріали до уроків          Українська мова
# 4   Розгорнутий календарний план. Літо. Молодший вік          Українська мова
#
#   Перекладач Мова оригіналу Оригінальна назва   Назва видавця Рік видання  \
# 0        NaN            NaN               NaN           Ранок        2024
# 1        NaN            NaN               NaN  Знання України        2005
# ...

# %%
df.to_excel('book_data.xlsx')
